# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
x = np.arange(0, 100, 0.3)
y = np.sin(x)

plt.plot(x, y)

plt.show()

# %%
path = "ppgHeartBeat.csv" # Raw PPG Signal Capture by phone camera
heartbeat = []
with open(path) as f:
    for line in f:
        heartbeat.append(float(line))
        
plt.plot(heartbeat)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# how much I spent for this week
name_list = ['Mon','Tue','Wed','Thu', 'Fri', 'Saturday', 'Sunday']
num_list = [32, 29, 18, 40, 33, 27, 30]
plt.bar(range(len(num_list)), num_list,tick_label=name_list)
plt.show()
